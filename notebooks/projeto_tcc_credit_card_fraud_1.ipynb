# %%
# !git clone https://github.com/ggentile/credit_card_fraud_prediction.git
# Out:
# Cloning into 'credit_card_fraud_prediction'...
# warning: You appear to have cloned an empty repository.

# %%
import pandas as pd

# %% [markdown]
# #### Primeiramente, carregar os dados e certificar-se que não há valores nulos

# %%
df = pd.read_csv('/content/credit_card_fraud_prediction/dataset/creditcard_2023.csv')

# %%
df.describe()
# Out:
#                   id             V1             V2             V3  \
# count  475397.000000  475397.000000  475397.000000  475397.000000
# mean   237698.000000       0.098899      -0.095821       0.133241
# std    137235.437298       0.989082       0.969039       0.987578
# min         0.000000      -3.495584     -49.966572      -3.183760
# 25%    118849.000000      -0.457378      -0.529734      -0.489320
# 50%    237698.000000      -0.036242      -0.208657       0.129779
# 75%    356547.000000       0.921697       0.199110       0.747236
# max    475396.000000       2.229046       4.361865      14.125834
#
#                   V4             V5             V6             V7  \
# count  475397.000000  475397.000000  475397.000000  475397.000000
# mean       -0.143751       0.066131       0.084365       0.095704
# std         0.989414       0.952810       0.968527       0.966109
# min        -4.951222      -9.952786     -21.111108      -4.351839
# 25%        -0.796438      -0.205154      -0.311787      -0.136081
# 50%        -0.238969       0.120916       0.136981       0.295194
# 75%         0.529049       0.458488       0.544499       0.554210
# max         3.201536      42.716891      26.168402     217.873038
#
#                   V8             V9  ...            V21            V22  \
# count  475397.000000  475397.000000  ...  475397.000000  475396.000000
# mean       -0.027390       0.114220  ...      -0.021559      -0.003031
# std         0.905588       0.982515  ...       0.906884       0.944092
# min       -10.756342      -3.751919  ...     -19.382523      -7.734798
# 25%        -0.194007      -0.388081  ...      -0.175046      -0.497269
# 50%        -0.123645       0.195979  ...      -0.059107      -0.029610
# 75%         0.015244       0.638718  ...       0.102651       0.462984
# max         5.958040      20.270062  ...       8.087080      12.632511
#
#                  V23            V24            V25            V26  \
# count  475396.000000  475396.000000  475396.000000  475396.000000
# mean       -0.002449       0.025854      -0.011709      -0.014125
# std         0.939944       1.028124       0.971831       1.017187
# min       -30.295450      -4.067968     -13.612633      -8.226969
# 25%        -0.226402      -0.643228      -0.561912      -0.664023
# 50%        -0.054256       0.039982      -0.016934      -0.030362
# 75%         0.148768       0.757174       0.540203       0.647644
# max        31.707627      12.965639      14.621509       5.623285
#
#                  V27            V28         Amount          Class
# count  475396.000000  475396.000000  475396.000000  475396.000000
# mean       -0.041343      -0.020294   12037.851572       0.401941
# std         0.929152       0.964307    6922.348551       0.490291
# min       -10.498633     -39.035243      50.010000       0.000000
# 25%        -0.308951      -0.230733    6046.737500       0.000000
# 50%        -0.193501      -0.032090   12023.925000       0.000000
# 75%         0.194942       0.317256   18039.237500       1.000000
# max       113.231093      77.255937   24039.930000       1.000000
#
# [8 rows x 31 columns]

# %% [markdown]
# ### Features do nosso dataset possui seguintes descrições:
# - id: Identificador único de cada transação
# - V1-V28: Features anonimizadas representando vários atributos de transação (e.g., hora, local, etc.)
# - Amount: Quantia da transação
# - Class: Label binário indicando se a transação é fraudulenta (1) ou não (0)
#
# ---

# %%
df = df.dropna()

# %% [markdown]
# ### Na sequência, precisamos remover a coluna de ID já que não queremos que o modelo tente encontrar padrões com relação a coluna

# %%
df_new = df.drop(columns=['id'])

# %%
df_new.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -0.260648 -0.469648  2.496266 -0.083724  0.129681  0.732898  0.519014
# 1  0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605  0.406466
# 2 -0.260272 -0.949385  1.728538 -0.457986  0.074062  1.419481  0.743511
# 3 -0.152152 -0.508959  1.746840 -1.090178  0.249486  1.143312  0.518269
# 4 -0.206820 -0.165280  1.527053 -0.448293  0.106125  0.530549  0.658849
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0 -0.130006  0.727159  0.637735  ... -0.110552  0.217606 -0.134794  0.165959
# 1 -0.133118  0.347452  0.529808  ... -0.194936 -0.605761  0.079469 -0.577395
# 2 -0.095576 -0.261297  0.690708  ... -0.005020  0.702906  0.945045 -1.154666
# 3 -0.065130 -0.205698  0.575231  ... -0.146927 -0.038212 -0.214048 -1.893131
# 4 -0.212660  1.049921  0.968046  ... -0.106984  0.729727 -0.161666  0.312561
#
#         V25       V26       V27       V28    Amount  Class
# 0  0.126280 -0.434824 -0.081230 -0.151045  17982.10    0.0
# 1  0.190090  0.296503 -0.248052 -0.064512   6531.37    0.0
# 2 -0.605564 -0.312895 -0.300258 -0.244718   2513.54    0.0
# 3  1.003963 -0.515950 -0.165316  0.048424   5384.44    0.0
# 4 -0.414116  1.071126  0.023712  0.419117  14278.97    0.0
#
# [5 rows x 30 columns]

# %% [markdown]
# ### Agora precisamos separar as features do target
# ---

# %%
x = df_new.drop(columns=['Class'])
y = df_new['Class']

# %% [markdown]
# ### Vamos fazer a primeira divisão de dados entre valores the teste para o dataset em 15% para teste final

# %%
from sklearn.model_selection import train_test_split

# %%
x_temp, x_test, y_temp, y_test = train_test_split(x, y, test_size=0.15, random_state=42)

# %% [markdown]
# ### Nesse caso, vamos separar o restante dos 85% dos valores em 15% para validação, sendo assim necessário realizar o cálculo de 15% de 85%

# %%
x_train, x_val, y_train, y_val = train_test_split(x_temp, y_temp, test_size=0.176,
                                                  random_state=42)

# %% [markdown]
# ### Por fim, antes de treinar nosso modelo, vamos redimensionar a coluna 'Amount' para nosso modelo

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# %%
x_train['Amount'] = scaler.fit_transform(x_train[['Amount']])
x_val['Amount'] = scaler.transform(x_val[['Amount']])
x_test['Amount'] = scaler.transform(x_test[['Amount']])

# %%
print(x_train)
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 231606 -0.102473 -0.652691  0.463024 -0.660760  0.096184  0.814806  0.280442
# 381351 -0.017798  0.066106  0.070130  0.646641 -0.203722  0.496036 -0.270224
# 154245  0.098366 -0.913348  0.536179 -1.602955  0.188735  0.055106  0.327817
# 354086 -0.641020  0.543822 -0.793124  0.483579 -0.611169  0.336566 -0.259312
# 41017  -0.374956 -0.279618  1.814349 -0.173007 -0.009103  0.773473  0.134453
# ...          ...       ...       ...       ...       ...       ...       ...
# 2542    0.025771 -0.238330  1.237696 -1.837823  0.316261 -0.279263  0.869172
# 246888 -0.226923 -0.163278  0.821819 -2.501420  0.627052 -0.118726  0.916926
# 392499 -1.782287  1.787302 -1.937259  1.359386 -2.091584 -2.639148 -1.823486
# 202533  0.042719 -0.383162  0.883303 -1.716314  0.355627  0.666767  0.401571
# 359957  0.749257 -0.255886  0.968193  0.282499  0.357472  0.783798  0.467833
#
#               V8        V9       V10  ...       V20       V21       V22  \
# 231606 -0.677346  0.320936  0.203839  ...  1.086831 -0.522078  0.155714
# 381351  0.130200 -0.495638 -0.068367  ...  0.180588  0.142691  0.258781
# 154245 -0.186332 -0.122221  1.155313  ... -0.148399 -0.030283  0.726616
# 354086 -0.366853 -0.773958 -0.789780  ...  0.231063 -0.361986  0.248692
# 41017   0.128176  0.773452  0.169972  ... -0.493972  0.003668  0.906617
# ...          ...       ...       ...  ...       ...       ...       ...
# 2542   -0.218677  1.097147  0.185809  ... -0.207293 -0.061720  0.620632
# 246888 -0.157812  0.498383  0.034683  ... -0.335628 -0.212768 -0.818643
# 392499  2.500764 -1.072061 -1.867407  ... -0.179032  0.748966 -0.296778
# 202533 -0.095240 -0.083417  0.503505  ...  0.333988 -0.180798 -0.583402
# 359957 -0.117066  0.032846  0.972817  ... -0.326056 -0.138532 -0.141064
#
#              V23       V24       V25       V26       V27       V28    Amount
# 231606 -0.430313  1.698511  0.815182  0.560354 -0.272162  0.652160  0.228082
# 381351 -0.105309 -0.769714 -0.341832  0.500699  0.422256  0.406405 -0.137572
# 154245  0.188901 -0.825062 -1.095035  0.228092 -0.084380  0.395125 -0.011762
# 354086 -0.183587  0.858024 -0.209326 -1.023901 -0.049028 -0.194702 -0.636523
# 41017  -0.434881  0.394011  0.107374 -0.389920 -0.298399 -0.489567 -0.231557
# ...          ...       ...       ...       ...       ...       ...       ...
# 2542   -0.243677  0.832425 -0.180247 -2.161638  0.065148 -0.135965 -1.377493
# 246888 -0.340925  1.331782  1.040037  0.153708 -0.762526 -0.737056 -0.761460
# 392499 -0.693297  0.525320  0.607094 -0.302694 -0.725793 -0.414262  0.176786
# 202533 -0.305596 -2.376604  0.878945 -0.443040  0.002476 -0.060930 -0.037658
# 359957 -0.014901  0.331953  0.377849 -0.221335 -0.280535 -0.178219 -0.326741
#
# [332966 rows x 29 columns]

# %%
# !git init
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/.git/

# %%
# !git config --global init.defaultBranch main
# !git config --global user.name "ggentile"
# !git config --global user.email "giannikleiss4@gmail.com"

# %%
# !git add projeto_tcc_credit_card_fraud_1.ipynb
# Out:
# fatal: pathspec 'projeto_tcc_credit_card_fraud_1.ipynb' did not match any files

# %%
import os
# List files to find the correct notebook name
print("Current files in /content:")
print([f for f in os.listdir('.') if f.endswith('.ipynb')])
# Out:
# Current files in /content:
# []

# %%
# 1. Create directory
# !mkdir -p notebooks

# 2. Move the notebook (Replacing 'projeto_tcc_credit_card_fraud_1.ipynb' with the actual filename if different)
# Assuming the file is indeed the one you tried to add:
# !mv *.ipynb notebooks/ 2>/dev/null || echo "No notebook files found to move"

# 3. Add, commit, and prepare push
# !git add notebooks/
# !git commit -m "Move notebook to notebooks folder"

# 4. Push to GitHub
# Replace <TOKEN> and <USERNAME/REPO> with your actual details
# !git remote add origin https://<TOKEN>@github.com/ggentile/credit_card_fraud_prediction.git
# !git push -u origin main
# Out:
# No notebook files found to move
# On branch master
#
# Initial commit
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	.config/
# 	credit_card_fraud_prediction/
# 	creditcard_2023.csv
#
# nothing added to commit but untracked files present (use "git add" to track)
