# %% [markdown]
# # Projeto TCC - Credit Card Fraud Detection (Parte 2)

# %% [markdown]
# ### Implementação do Autoencoder para Detecção de Anomalias

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
